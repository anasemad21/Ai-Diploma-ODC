# %% [markdown]
# # code of power pi inside jupyter?

# %% [markdown]
# What is Power BI?
# Microsoft’s Power BI is a business and data analytics service that enables professionals to process, analyze, and visualize vast volumes of data. It helps extract insights, draw conclusions, and share results in the form of reports and dashboards across various departments. It provides an easy drag and drops feature with a range of interactive data visualizations to generate reports and dashboards.
#
# Features of Power BI
# -Power BI is faster and performs better when there is a smaller volume of data
# -Power BI provides an interface based on Microsoft Office 365 that is user-friendly, intuitive, and easy to understand
# Using Power BI, you can work with several data sources, such as Excel, Text/CSV, JSON, SQL Server databases, IBM DB2, MySQL, etc.
# -Power BI can connect with the R programming language, and it also supports various Data Analysis Expression (DAX) functions and measures
# -Power BI has functional integration with the Microsoft Azure cloud platform. It helps to analyze insights and patterns in datasets
#
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# ->>> install powerbiclient
#
#
# from powerbiclient import Report, models
# from powerbiclient.authentication import DeviceCodeLoginAuthentication
#
# https://powerbi.microsoft.com/en-us/blog/announcing-power-bi-in-jupyter-notebooks/

# %% [markdown]
# # ALL data types ,and max number you can store in it

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
#
#
# max number->>>
# INT_MIN:  −2147483648
# Defines the minimum value for an int.
#
# INT_MAX:  +2147483647
# Defines the maximum value for an int.
#
# UINT_MAX: 4294967295
# Defines the maximum value for an unsigned int.
#
# LONG_MAX:+9223372036854775807
# Defines the maximum value for a long int.
#
# ULONG_MAX: 18446744073709551615
# Defines the maximum value for an unsigned long int.

# %% [markdown]
# # Ways to Randomly Select Rows from Pandas DataFrame

# %% [markdown]
# df = df.sample() #Randomly select a single row
# df = df.sample(n=3) #Randomly select a specified number of rows
# df = df.sample(n=3,replace=True) # Allow a random selection of the same row more than once (by setting replace=True)
# df = df.sample(frac=0.50) #Randomly select a specified fraction of the total number of rows

# %% [markdown]
# # How to append df on the same file of data?

# %%
import pandas as pd
 
# add new rows 
data = {
    'Name': ['Hardik', 'Pollard', 'Bravo'],
    'Run': [50, 63, 15],
    'Wicket': [0, 2, 3],
    'Catch': [4, 2, 1]
}
 
# Make data frame of above data
df = pd.DataFrame(data)
 
# append data frame to CSV file
df.to_csv('GFG.csv', mode='a', index=False, header=False)


# add new columns
# Define a dictionary containing Students data
data = {'Name': ['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Height': [5.1, 6.2, 5.1, 5.2],
        'Qualification': ['Msc', 'MA', 'Msc', 'Msc']}
  
# Convert the dictionary into DataFrame
df = pd.DataFrame(data)
  
# Declare a list that is to be converted into a column
address = ['Delhi', 'Bangalore', 'Chennai', 'Patna']
  
# Using 'Address' as the column name
# and equating it to the list
df['Address'] = address
  
# Observe the result
print(df)
# Out:
#      Name  Height Qualification    Address
# 0     Jai     5.1           Msc      Delhi
# 1  Princi     6.2            MA  Bangalore
# 2  Gaurav     5.1           Msc    Chennai
# 3    Anuj     5.2           Msc      Patna

# %% [markdown]
# # Lambda expression

# %%
# lambda arguments : expression
x = lambda a, b : a * b
print(x(5, 6))


def myfunc(n):
  return lambda a : a * n

mydoubler = myfunc(2)

print(mydoubler(11))
# Out:
# 30
# 22

# %% [markdown]
# # how to combine more than 2 dataframes at the same time

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://www.statology.org/pandas-merge-multiple-dataframes/
